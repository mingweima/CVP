# %%
import numpy as np

bbox = np.load('/Volumes/T5/cvpdata/shapestacks/frc_35/env_ccs-hard-h=5-vcom=2-vpsf=0-v=45/cam_1.npy')

# %%
bbox
# Out:
# array([[[0.78472577, 0.03364887],
#         [0.888085  , 0.25569174],
#         [0.76453077, 0.44418668],
#         [0.88556764, 0.68300804],
#         [0.81988778, 0.90125916]],
#
#        [[0.78440902, 0.03867514],
#         [0.88735422, 0.25940036],
#         [0.76471821, 0.44631918],
#         [0.88566971, 0.68348718],
#         [0.81990085, 0.90143393]],
#
#        [[0.78367769, 0.03941517],
#         [0.88578322, 0.25862166],
#         [0.76522242, 0.44651352],
#         [0.88618354, 0.68326163],
#         [0.81993301, 0.90133293]],
#
#        [[0.78184422, 0.04122026],
#         [0.88278831, 0.25752146],
#         [0.76590924, 0.44682855],
#         [0.8872336 , 0.68294915],
#         [0.81996056, 0.90134922]],
#
#        [[0.77868104, 0.04282872],
#         [0.87794666, 0.25583797],
#         [0.76612051, 0.4472984 ],
#         [0.88826977, 0.68258055],
#         [0.81998016, 0.9013434 ]],
#
#        [[0.77358765, 0.04519607],
#         [0.8709211 , 0.25384413],
# ...
